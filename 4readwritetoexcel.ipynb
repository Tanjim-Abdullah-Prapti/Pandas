# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-55383760-c3fc-4e7e-85cb-1b14f9cb5f7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55383760-c3fc-4e7e-85cb-1b14f9cb5f7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving new4.csv to new4 (2).csv
# Saving new4.xlsx to new4 (1).xlsx
# Saving stock_data4.csv to stock_data4 (2).csv
# Saving stock_data4.xlsx to stock_data4 (1).xlsx
# Saving stocks_weather4.csv to stocks_weather4 (2).csv
# Saving stocks_weather4.xlsx to stocks_weather4 (1).xlsx
# {'new4.csv': b'tickers,eps,revenue,price,people\r\nGOOGL,27.82,87,845,larry page\r\nWMT,4.61,484,65,Sam Walton\r\nMSFT,-1,85,64,bill gates\r\nRIL ,not available,50,1023,mukesh ambani\r\nTATA,5.6,-1,50,ratan tata\r\n',
# ...

# %%
df = pd.read_csv("stock_data4.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("stock_data4.csv", header=1) # skiprows and header are kind of same
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv("stock_data4.csv", header=None, names = ["ticker","eps","revenue","people"])
df
# Out:
#                 ticker      eps revenue         people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
df = pd.read_csv("stock_data4.csv",  nrows=2)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
df = pd.read_csv("stock_data4.csv", na_values=["n.a.", "not available"])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv("stock_data4.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['not available','n.a.']
    })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.to_csv("new.csv4", index=False)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("new.csv4",header=False)

# %%
df.to_csv("new.csv4", columns=["tickers","price"], index=False)

# %%
df = pd.read_excel("stock_data4.xlsx","Sheet1")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Sam Walton'
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return 50
    return cell
    
df = pd.read_excel("stock_data4.xlsx","Sheet1", converters= {
        'people': convert_people_cell,
        'price': convert_price_cell
    })
df
# Out:
#   tickers            eps  revenue  price         people
# 0   GOOGL          27.82       87    845     larry page
# 1     WMT           4.61      484     65     Sam Walton
# 2    MSFT             -1       85     64     bill gates
# 3    RIL   not available       50   1023  mukesh ambani
# 4    TATA            5.6       -1     50     ratan tata

# %%
df.to_excel("new.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weather4.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")
